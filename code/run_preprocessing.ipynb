# %%
## Script that will run the raw data through our preprocessing pipeline
# Work in progress: installing fmriPrep on mac os x "baremetal" is challenging

# %%
import os
import subprocess

# %%
subject_idx = 6

# %%
# make a sub-xx directory in ~/PROJECTS/fus/data/fmriprep_out
if not os.path.exists(f'/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-{subject_idx:02d}'):
    os.makedirs(f'/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-{subject_idx:02d}')

# %%
fmriprep_call = f"fmriprep /Users/jacekdmochowski/PROJECTS/fus/data/bold /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out participant -w /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working --fs-license-file ~/license.txt --mem 64000000000 --nprocs 10 --participant-label {subject_idx:02d}"

# %%
print(fmriprep_call)
# Out:
# fmriprep /Users/jacekdmochowski/PROJECTS/fus/data/bold /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out participant -w /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working --fs-license-file ~/license.txt --mem 64000000000 --nprocs 10 --participant-label 06

# %%
return_code = subprocess.call([fmriprep_call], shell=True)
# Out:
# 240619-15:58:43,442 cli WARNING:
# 	 Telemetry disabled because sentry_sdk is not installed.
# bids-validator@1.14.4
# 	1: [WARN] The recommended file /README is missing. See Section 03 (Modality agnostic files) of the BIDS specification. (code: 101 - README_FILE_MISSING)
#
# 	Please visit https://neurostars.org/search?q=README_FILE_MISSING for existing conversations about this issue.
#
#         Summary:                Available Tasks:        Available Modalities:
#         36 Files, 5.31GB                                MRI
#         5 - Subjects
#         1 - Session
#
#
# 	If you have any questions, please post on https://neurostars.org/tags/bids.
# (node:83901) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# (node:83901) Warning: Closing directory handle on garbage collection
# 240619-15:58:51,505 nipype.workflow IMPORTANT:
# 	 Running fMRIPrep version 24.0.0
#
#          License NOTICE ##################################################
#          fMRIPrep 24.0.0
#          Copyright The NiPreps Developers.
#
#          This product includes software developed by
#          the NiPreps Community (https://nipreps.org/).
#
#          Portions of this software were developed at the Department of
#          Psychology at Stanford University, Stanford, CA, US.
#
#          This software is also distributed as a Docker container image.
#          The bootstrapping file for the image ("Dockerfile") is licensed
#          under the MIT License.
#
#          This software may be distributed through an add-on package called
#          "Docker Wrapper" that is under the BSD 3-clause License.
#          #################################################################
# 240619-15:58:51,507 nipype.workflow WARNING:
# 	 Previous output generated by version 23.2.1 found.
# 240619-15:58:51,514 nipype.workflow IMPORTANT:
# 	 Building fMRIPrep's workflow:
#            * BIDS dataset path: /Users/jacekdmochowski/PROJECTS/fus/data/bold.
#            * Participant list: ['06'].
#            * Run identifier: 20240619-155842_f22409a1-275c-45ea-a261-acd3a3702756.
#            * Output spaces: MNI152NLin2009cAsym:res-native.
#            * Pre-run FreeSurfer's SUBJECTS_DIR: /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sourcedata/freesurfer.
# 240619-15:58:51,764 nipype.workflow INFO:
# 	 ANAT Stage 1: Adding template workflow
# 240619-15:58:52,427 nipype.workflow INFO:
# 	 ANAT Stage 2: Preparing brain extraction workflow
# 240619-15:58:52,479 nipype.workflow INFO:
# 	 ANAT Stage 3: Preparing segmentation workflow
# 240619-15:58:52,482 nipype.workflow INFO:
# 	 ANAT Stage 4: Preparing normalization workflow for ['MNI152NLin2009cAsym']
# 240619-15:58:52,488 nipype.workflow INFO:
# 	 ANAT Stage 5: Preparing surface reconstruction workflow
# 240619-15:58:52,500 nipype.workflow INFO:
# 	 ANAT Stage 6: Preparing mask refinement workflow
# 240619-15:58:52,502 nipype.workflow INFO:
# 	 ANAT No T2w images provided - skipping Stage 7
# 240619-15:58:52,502 nipype.workflow INFO:
# 	 ANAT Stage 8: Creating GIFTI surfaces for ['white', 'pial', 'midthickness', 'sphere_reg', 'sphere']
# 240619-15:58:52,513 nipype.workflow INFO:
# 	 ANAT Stage 8: Creating GIFTI metrics for ['thickness', 'sulc']
# 240619-15:58:52,517 nipype.workflow INFO:
# 	 ANAT Stage 8a: Creating cortical ribbon mask
# 240619-15:58:52,520 nipype.workflow INFO:
# 	 ANAT Stage 9: Creating fsLR registration sphere
# 240619-15:58:52,523 nipype.workflow INFO:
# 	 ANAT Stage 10: Creating MSM-Sulc registration sphere
# 240619-15:58:52,689 nipype.workflow INFO:
# 	 No single-band-reference found for sub-06_task-prefuspost_bold.nii.gz.
# 240619-15:58:52,760 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240619-15:58:52,764 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240619-15:58:52,789 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240619-15:58:57,338 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.435s.
# 240619-15:59:00,848 nipype.workflow INFO:
# 	 fMRIPrep workflow graph with 397 nodes built successfully.
# 240619-15:59:27,455 nipype.workflow IMPORTANT:
# 	 fMRIPrep started!
# 240619-15:59:29,996 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.res_tmpl" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/res_tmpl".
# 240619-15:59:29,998 nipype.workflow INFO:
# 	 [Node] Executing "res_tmpl" <niworkflows.interfaces.nibabel.RegridToZooms>
# 240619-15:59:30,4 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.full_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/full_wm".
# 240619-15:59:30,12 nipype.workflow INFO:
# 	 [Node] Executing "full_wm" <nipype.interfaces.utility.wrappers.Function>
# 240619-15:59:30,514 nipype.workflow INFO:
# 	 [Node] Finished "full_wm", elapsed time 0.433968s.
# 240619-15:59:30,535 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/lap_tmpl".
# 240619-15:59:30,546 nipype.workflow INFO:
# 	 [Node] Executing "lap_tmpl" <nipype.interfaces.ants.utils.ImageMath>
# 240619-15:59:30,719 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.hmc_boldref_wf.val_bold" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/val_bold".
# 240619-15:59:30,721 nipype.workflow INFO:
# 	 [Node] Executing "val_bold" <niworkflows.interfaces.header.ValidateImage>
# 240619-15:59:30,764 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.hmc_boldref_wf.get_dummy" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/get_dummy".
# 240619-15:59:30,766 nipype.workflow INFO:
# 	 [Node] Executing "get_dummy" <niworkflows.interfaces.bold.NonsteadyStatesDetector>
# 240619-15:59:30,795 nipype.workflow INFO:
# 	 [Node] Finished "val_bold", elapsed time 0.02433s.
# 240619-15:59:30,890 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bidssrc" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bidssrc".
# 240619-15:59:30,893 nipype.workflow INFO:
# 	 [Node] Executing "bidssrc" <niworkflows.interfaces.bids.BIDSDataGrabber>
# 240619-15:59:30,901 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_native_wf.bold_source" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_native_wf/bold_source".
# 240619-15:59:30,903 nipype.workflow INFO:
# 	 [Node] Executing "bold_source" <nipype.interfaces.utility.base.Select>
# 240619-15:59:30,928 nipype.workflow INFO:
# 	 [Node] Finished "bold_source", elapsed time 0.000521s.
# 240619-15:59:30,934 nipype.interface INFO:
# 	 No "t2w" images found for sub-06
# 240619-15:59:30,935 nipype.interface INFO:
# 	 No "flair" images found for sub-06
# 240619-15:59:30,935 nipype.interface INFO:
# 	 No "fmap" images found for sub-06
# 240619-15:59:30,935 nipype.interface INFO:
# 	 No "sbref" images found for sub-06
# 240619-15:59:30,935 nipype.interface INFO:
# 	 No "roi" images found for sub-06
# 240619-15:59:30,936 nipype.interface INFO:
# 	 No "pet" images found for sub-06
# 240619-15:59:30,936 nipype.interface INFO:
# 	 No "asl" images found for sub-06
# 240619-15:59:30,937 nipype.workflow INFO:
# 	 [Node] Finished "bidssrc", elapsed time 0.002725s.
# 240619-15:59:31,221 nipype.workflow INFO:
# 	 [Node] Finished "res_tmpl", elapsed time 1.138363s.
# 240619-15:59:31,404 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_hmc_wf.sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_hmc_wf/sources".
# 240619-15:59:31,406 nipype.workflow INFO:
# 	 [Node] Executing "sources" <fmriprep.interfaces.bids.BIDSURI>
# 240619-15:59:31,406 nipype.workflow INFO:
# 	 [Node] Finished "sources", elapsed time 0.000101s.
# 240619-15:59:31,496 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_hmc_boldref_wf.sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_hmc_boldref_wf/sources".
# 240619-15:59:31,498 nipype.workflow INFO:
# 	 [Node] Executing "sources" <fmriprep.interfaces.bids.BIDSURI>
# 240619-15:59:31,512 nipype.workflow INFO:
# 	 [Node] Finished "sources", elapsed time 0.000425s.
# 240619-15:59:31,593 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_boldmask_wf.sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_boldmask_wf/sources".
# 240619-15:59:31,595 nipype.workflow INFO:
# 	 [Node] Executing "sources" <fmriprep.interfaces.bids.BIDSURI>
# 240619-15:59:31,607 nipype.workflow INFO:
# 	 [Node] Finished "sources", elapsed time 0.000426s.
# 240619-15:59:31,997 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.anat_template_wf.anat_ref_dimensions" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/anat_template_wf/anat_ref_dimensions".
# 240619-15:59:31,999 nipype.workflow INFO:
# 	 [Node] Executing "anat_ref_dimensions" <niworkflows.interfaces.images.TemplateDimensions>
# 240619-15:59:32,1 nipype.workflow INFO:
# 	 [Node] Finished "anat_ref_dimensions", elapsed time 0.001814s.
# 240619-15:59:32,238 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_native_wf.validate_bold" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_native_wf/validate_bold".
# 240619-15:59:32,240 nipype.workflow INFO:
# 	 [Node] Executing "validate_bold" <niworkflows.interfaces.header.ValidateImage>
# 240619-15:59:32,275 nipype.workflow INFO:
# 	 [Node] Finished "validate_bold", elapsed time 0.022963s.
# 240619-15:59:32,658 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bids_info" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bids_info".
# 240619-15:59:32,660 nipype.workflow INFO:
# 	 [Node] Executing "bids_info" <niworkflows.interfaces.bids.BIDSInfo>
# 240619-15:59:32,664 nipype.workflow INFO:
# 	 [Node] Finished "bids_info", elapsed time 0.002744s.
# 240619-15:59:34,438 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.fs_isrunning" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/fs_isrunning".
# 240619-15:59:34,439 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.ds_t1w_mask_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/ds_t1w_mask_wf/raw_sources".
# 240619-15:59:34,439 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.ds_ribbon_mask_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/ds_ribbon_mask_wf/raw_sources".
# 240619-15:59:34,444 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240619-15:59:34,444 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240619-15:59:34,445 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000245s.
# 240619-15:59:34,445 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000253s.
# 240619-15:59:35,76 nipype.workflow INFO:
# 	 [Node] Finished "get_dummy", elapsed time 4.244792s.
# 240619-15:59:35,133 nipype.workflow INFO:
# 	 [Node] Executing "fs_isrunning" <nipype.interfaces.utility.wrappers.Function>
# 240619-15:59:35,145 nipype.workflow INFO:
# 	 [Node] Finished "fs_isrunning", elapsed time 0.000698s.
# 240619-15:59:35,377 nipype.workflow INFO:
# 	 [Node] Finished "lap_tmpl", elapsed time 4.609652s.
# 240619-15:59:35,778 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.mrg_tmpl" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/mrg_tmpl".
# 240619-15:59:35,781 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.hmc_boldref_wf.gen_avg" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/gen_avg".
# 240619-15:59:35,792 nipype.workflow INFO:
# 	 [Node] Executing "mrg_tmpl" <nipype.interfaces.utility.base.Merge>
# 240619-15:59:35,792 nipype.workflow INFO:
# 	 [Node] Executing "gen_avg" <niworkflows.interfaces.images.RobustAverage>
# 240619-15:59:35,793 nipype.workflow INFO:
# 	 [Node] Finished "mrg_tmpl", elapsed time 8.5e-05s.
# 240619-15:59:35,874 nipype.workflow INFO:
# 	 [Node] Setting-up "_denoise0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/anat_template_wf/denoise/mapflow/_denoise0".
# 240619-15:59:35,875 nipype.workflow INFO:
# 	 [Node] Executing "_denoise0" <nipype.interfaces.ants.segmentation.DenoiseImage>
# 240619-15:59:39,737 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_native_wf.bold_stc_wf.slice_timing_correction" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_native_wf/bold_stc_wf/slice_timing_correction".
# 240619-15:59:39,740 nipype.workflow INFO:
# 	 [Node] Executing "slice_timing_correction" <fmriprep.workflows.bold.stc.TShift>
# 240619-15:59:42,626 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.625739:++ 3dvolreg: AFNI version=AFNI_22.3.03 (Oct 13 2022) [64-bit]
# 240619-15:59:42,627 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.625739:++ Authored by: RW Cox
# 240619-15:59:42,628 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:** AFNI converts NIFTI_datatype=512 (UINT16) in file /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/gen_avg/sub-06_task-prefuspost_bold_sliced.nii.gz to FLOAT32
# 240619-15:59:42,629 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:     Warnings of this type will be muted for this session.
# 240619-15:59:42,629 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 240619-15:59:42,629 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:*+ WARNING:   If you are performing spatial transformations on an oblique dset,
# 240619-15:59:42,629 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:  such as /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/gen_avg/sub-06_task-prefuspost_bold_sliced.nii.gz,
# 240619-15:59:42,629 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:  or viewing/combining it with volumes of differing obliquity,
# 240619-15:59:42,629 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:  you should consider running:
# 240619-15:59:42,630 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:     3dWarp -deoblique
# 240619-15:59:42,630 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:  on this and  other oblique datasets in the same session.
# 240619-15:59:42,630 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699: See 3dWarp -help for details.
# 240619-15:59:42,630 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:++ Oblique dataset:/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/gen_avg/sub-06_task-prefuspost_bold_sliced.nii.gz is 19.331402 degrees from plumb.
# 240619-15:59:42,630 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:42.628699:++ Coarse del was 10, replaced with 7
# 240619-15:59:48,567 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:48.566452:++ Max displacement in automask = 0.05 (mm) at sub-brick 1
# 240619-15:59:48,567 nipype.interface INFO:
# 	 stderr 2024-06-19T15:59:48.566452:++ Max delta displ  in automask = 0.05 (mm) at sub-brick 1
# 240619-15:59:49,29 nipype.workflow INFO:
# 	 [Node] Finished "gen_avg", elapsed time 13.235987s.
# 240619-15:59:49,790 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.fmapref_buffer" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/fmapref_buffer".
# 240619-15:59:49,799 nipype.workflow INFO:
# 	 [Node] Executing "fmapref_buffer" <nipype.interfaces.utility.wrappers.Function>
# 240619-15:59:49,801 nipype.workflow INFO:
# 	 [Node] Finished "fmapref_buffer", elapsed time 0.000296s.
# 240619-15:59:51,807 nipype.interface WARNING:
# 	 Changing /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/func/sub-06_task-prefuspost_desc-hmc_boldref.nii.gz dtype from uint16 to float32
# 240619-15:59:52,33 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.bold_hmc_wf.mcflirt" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/bold_hmc_wf/mcflirt".
# 240619-15:59:52,37 nipype.workflow INFO:
# 	 [Node] Executing "mcflirt" <nipype.interfaces.fsl.preprocess.MCFLIRT>
# 240619-16:00:30,790 nipype.workflow INFO:
# 	 [Node] Finished "_denoise0", elapsed time 54.807409s.
# 240619-16:00:31,960 nipype.workflow INFO:
# 	 [Node] Setting-up "_anat_conform0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/anat_template_wf/anat_conform/mapflow/_anat_conform0".
# 240619-16:00:31,962 nipype.workflow INFO:
# 	 [Node] Executing "_anat_conform0" <niworkflows.interfaces.images.Conform>
# 240619-16:00:31,963 nipype.workflow INFO:
# 	 [Node] Finished "_anat_conform0", elapsed time 0.00112s.
# 240619-16:00:32,572 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_coreg_boldref_wf.sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_coreg_boldref_wf/sources".
# 240619-16:00:32,575 nipype.workflow INFO:
# 	 [Node] Executing "sources" <fmriprep.interfaces.bids.BIDSURI>
# 240619-16:00:32,576 nipype.workflow INFO:
# 	 [Node] Finished "sources", elapsed time 0.00011s.
# 240619-16:00:33,904 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.init_aff" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/init_aff".
# 240619-16:00:33,907 nipype.workflow INFO:
# 	 [Node] Executing "init_aff" <nipype.interfaces.ants.utils.AI>
# 240619-16:00:51,882 nipype.workflow INFO:
# 	 [Node] Finished "init_aff", elapsed time 17.873656s.
# 240619-16:00:53,933 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.anat_template_wf.get1st" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/anat_template_wf/get1st".
# 240619-16:00:53,980 nipype.workflow INFO:
# 	 [Node] Executing "get1st" <nipype.interfaces.utility.base.Select>
# 240619-16:00:53,981 nipype.workflow INFO:
# 	 [Node] Finished "get1st", elapsed time 0.000119s.
# 240619-16:00:55,940 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.norm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/norm".
# 240619-16:00:55,943 nipype.workflow INFO:
# 	 [Node] Executing "norm" <niworkflows.interfaces.fixes.FixHeaderRegistration>
# 240619-16:00:56,372 nipype.workflow INFO:
# 	 [Node] Finished "norm", elapsed time 0.328328s.
# 240619-16:00:58,26 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.map_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/map_brainmask".
# 240619-16:00:58,29 nipype.workflow INFO:
# 	 [Node] Executing "map_brainmask" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240619-16:00:58,924 nipype.workflow INFO:
# 	 [Node] Finished "map_brainmask", elapsed time 0.799486s.
# 240619-16:00:59,950 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.surface_recon_wf.fov_check" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/surface_recon_wf/fov_check".
# 240619-16:00:59,952 nipype.workflow INFO:
# 	 [Node] Executing "fov_check" <nipype.interfaces.utility.wrappers.Function>
# 240619-16:00:59,966 nipype.workflow INFO:
# 	 [Node] Setting-up "_truncate_images0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/truncate_images/mapflow/_truncate_images0".
# 240619-16:00:59,969 nipype.workflow INFO:
# 	 [Node] Executing "_truncate_images0" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:01:00,31 nipype.workflow INFO:
# 	 [Node] Finished "fov_check", elapsed time 0.077738s.
# 240619-16:01:00,296 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.surface_recon_wf.recon_config" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/surface_recon_wf/recon_config".
# 240619-16:01:00,301 nipype.workflow INFO:
# 	 [Node] Executing "recon_config" <niworkflows.interfaces.freesurfer.FSDetectInputs>
# 240619-16:01:00,302 nipype.workflow INFO:
# 	 [Node] Finished "recon_config", elapsed time 0.000538s.
# 240619-16:01:01,34 nipype.workflow INFO:
# 	 [Node] Finished "_truncate_images0", elapsed time 0.939924s.
# 240619-16:01:01,964 nipype.workflow INFO:
# 	 [Node] Setting-up "_inu_n40" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/inu_n4/mapflow/_inu_n40".
# 240619-16:01:01,966 nipype.workflow INFO:
# 	 [Node] Executing "_inu_n40" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 240619-16:01:13,880 nipype.workflow INFO:
# 	 [Node] Finished "_inu_n40", elapsed time 11.815744s.
# 240619-16:01:14,276 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.surface_recon_wf.autorecon1" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/surface_recon_wf/autorecon1".
# 240619-16:01:14,281 nipype.workflow INFO:
# 	 [Node] Executing "autorecon1" <smriprep.interfaces.freesurfer.ReconAll>
# 240619-16:02:14,691 nipype.workflow INFO:
# 	 [Node] Finished "slice_timing_correction", elapsed time 154.949782s.
# 240619-16:02:16,127 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_native_wf.bold_stc_wf.copy_xform" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_native_wf/bold_stc_wf/copy_xform".
# 240619-16:02:17,669 nipype.workflow INFO:
# 	 [Node] Executing "copy_xform" <niworkflows.interfaces.header.CopyXForm>
# 240619-16:03:39,475 nipype.workflow INFO:
# 	 [Node] Finished "copy_xform", elapsed time 81.805311s.
# 240619-16:03:40,294 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.n4_correct" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/n4_correct".
# 240619-16:03:40,300 nipype.workflow INFO:
# 	 [Node] Executing "n4_correct" <niworkflows.interfaces.fixes.FixN4BiasFieldCorrection>
# 240619-16:03:42,66 nipype.workflow INFO:
# 	 [Node] Finished "n4_correct", elapsed time 1.7650700000000001s.
# 240619-16:03:42,305 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.res_target" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/res_target".
# 240619-16:03:42,307 nipype.workflow INFO:
# 	 [Node] Executing "res_target" <niworkflows.interfaces.nibabel.RegridToZooms>
# 240619-16:03:43,279 nipype.workflow INFO:
# 	 [Node] Finished "res_target", elapsed time 0.971533s.
# 240619-16:03:44,318 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.lap_target" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/lap_target".
# 240619-16:03:44,319 nipype.workflow INFO:
# 	 [Node] Executing "lap_target" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:03:47,427 nipype.workflow INFO:
# 	 [Node] Finished "lap_target", elapsed time 3.008633s.
# 240619-16:03:48,321 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.skullstrip_first_pass" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/skullstrip_first_pass".
# 240619-16:03:48,323 nipype.workflow INFO:
# 	 [Node] Executing "skullstrip_first_pass" <nipype.interfaces.fsl.preprocess.BET>
# 240619-16:03:49,343 nipype.workflow INFO:
# 	 [Node] Finished "skullstrip_first_pass", elapsed time 1.018422s.
# 240619-16:03:50,351 nipype.interface WARNING:
# 	 Changing /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/func/sub-06_task-prefuspost_desc-coreg_boldref.nii.gz dtype from uint16 to float32
# 240619-16:03:50,534 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.mrg_target" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/mrg_target".
# 240619-16:03:50,536 nipype.workflow INFO:
# 	 [Node] Executing "mrg_target" <nipype.interfaces.utility.base.Merge>
# 240619-16:03:50,537 nipype.workflow INFO:
# 	 [Node] Finished "mrg_target", elapsed time 9.3e-05s.
# 240619-16:03:52,336 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.first_dilate" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/first_dilate".
# 240619-16:03:52,364 nipype.workflow INFO:
# 	 [Node] Executing "first_dilate" <niworkflows.interfaces.nibabel.BinaryDilation>
# 240619-16:03:52,870 nipype.workflow INFO:
# 	 [Node] Finished "first_dilate", elapsed time 0.504994s.
# 240619-16:03:54,342 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_boldreg_wf.sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_boldreg_wf/sources".
# 240619-16:03:54,345 nipype.workflow INFO:
# 	 [Node] Executing "sources" <fmriprep.interfaces.bids.BIDSURI>
# 240619-16:03:54,346 nipype.workflow INFO:
# 	 [Node] Finished "sources", elapsed time 0.000102s.
# 240619-16:03:56,350 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_std_wf.gen_ref" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_std_wf/_in_tuple_MNI152NLin2009cAsym.resnative/gen_ref".
# 240619-16:03:56,353 nipype.workflow INFO:
# 	 [Node] Executing "gen_ref" <niworkflows.interfaces.nibabel.GenerateSamplingReference>
# 240619-16:03:57,424 nipype.workflow INFO:
# 	 [Node] Finished "gen_ref", elapsed time 1.069962s.
# 240619-16:03:58,358 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.first_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/first_mask".
# 240619-16:03:58,387 nipype.workflow INFO:
# 	 [Node] Executing "first_mask" <niworkflows.interfaces.nibabel.ApplyMask>
# 240619-16:03:58,448 nipype.workflow INFO:
# 	 [Node] Finished "first_mask", elapsed time 0.060786s.
# 240619-16:04:00,362 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.unifize" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/unifize".
# 240619-16:04:00,364 nipype.workflow INFO:
# 	 [Node] Executing "unifize" <nipype.interfaces.afni.utils.Unifize>
# 240619-16:04:56,800 nipype.workflow INFO:
# 	 [Node] Finished "unifize", elapsed time 56.434613s.
# 240619-16:04:58,524 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.fixhdr_unifize" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/fixhdr_unifize".
# 240619-16:04:58,542 nipype.workflow INFO:
# 	 [Node] Executing "fixhdr_unifize" <niworkflows.interfaces.header.CopyXForm>
# 240619-16:04:58,605 nipype.workflow INFO:
# 	 [Node] Finished "fixhdr_unifize", elapsed time 0.062683s.
# 240619-16:05:00,546 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.skullstrip_second_pass" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/skullstrip_second_pass".
# 240619-16:05:00,548 nipype.workflow INFO:
# 	 [Node] Executing "skullstrip_second_pass" <nipype.interfaces.afni.preprocess.Automask>
# 240619-16:05:01,302 nipype.workflow INFO:
# 	 [Node] Finished "skullstrip_second_pass", elapsed time 0.753328s.
# 240619-16:05:02,543 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.fixhdr_skullstrip2" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/fixhdr_skullstrip2".
# 240619-16:05:02,560 nipype.workflow INFO:
# 	 [Node] Executing "fixhdr_skullstrip2" <niworkflows.interfaces.header.CopyXForm>
# 240619-16:05:02,576 nipype.workflow INFO:
# 	 [Node] Finished "fixhdr_skullstrip2", elapsed time 0.014546s.
# 240619-16:05:04,539 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.combine_masks" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/combine_masks".
# 240619-16:05:04,545 nipype.workflow INFO:
# 	 [Node] Executing "combine_masks" <nipype.interfaces.fsl.maths.BinaryMaths>
# 240619-16:05:04,673 nipype.workflow INFO:
# 	 [Node] Finished "combine_masks", elapsed time 0.127916s.
# 240619-16:05:06,547 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.apply_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/apply_mask".
# 240619-16:05:06,549 nipype.workflow INFO:
# 	 [Node] Executing "apply_mask" <niworkflows.interfaces.nibabel.ApplyMask>
# 240619-16:05:06,609 nipype.workflow INFO:
# 	 [Node] Finished "apply_mask", elapsed time 0.059056s.
# 240619-16:05:08,560 nipype.interface WARNING:
# 	 Changing /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/func/sub-06_task-prefuspost_desc-brain_mask.nii.gz dtype from float32 to uint8
# 240619-16:06:03,68 nipype.workflow INFO:
# 	 [Node] Finished "mcflirt", elapsed time 371.03064s.
# 240619-16:06:04,683 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.bold_hmc_wf.normalize_motion" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/bold_hmc_wf/normalize_motion".
# 240619-16:06:04,713 nipype.workflow INFO:
# 	 [Node] Executing "normalize_motion" <niworkflows.interfaces.confounds.NormalizeMotionParams>
# 240619-16:06:04,719 nipype.workflow INFO:
# 	 [Node] Finished "normalize_motion", elapsed time 0.004595s.
# 240619-16:06:06,691 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_confounds_wf.fdisp" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_confounds_wf/fdisp".
# 240619-16:06:06,810 nipype.workflow INFO:
# 	 [Node] Executing "fdisp" <nipype.algorithms.confounds.FramewiseDisplacement>
# 240619-16:06:06,814 nipype.workflow INFO:
# 	 [Node] Finished "fdisp", elapsed time 0.003254s.
# 240619-16:14:25,79 nipype.workflow INFO:
# 	 [Node] Finished "autorecon1", elapsed time 790.797334s.
# 240619-16:14:25,885 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_fit_wf.bold_hmc_wf.fsl2itk" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_fit_wf/bold_hmc_wf/fsl2itk".
# 240619-16:14:25,987 nipype.workflow INFO:
# 	 [Node] Executing "fsl2itk" <niworkflows.interfaces.itk.MCFLIRT2ITK>
# 240619-16:14:25,988 nipype.interface WARNING:
# 	 Multithreading is deprecated. Remove the num_threads input.
# 240619-16:14:26,180 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.surface_recon_wf.fsnative2t1w_xfm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/surface_recon_wf/fsnative2t1w_xfm".
# 240619-16:14:26,184 nipype.workflow INFO:
# 	 [Node] Executing "fsnative2t1w_xfm" <niworkflows.interfaces.freesurfer.PatchedRobustRegister>
# 240619-16:14:26,398 nipype.workflow INFO:
# 	 [Node] Finished "fsl2itk", elapsed time 0.410252s.
# 240619-16:14:27,896 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.init_aff" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/init_aff".
# 240619-16:14:27,900 nipype.workflow INFO:
# 	 [Node] Executing "init_aff" <nipype.interfaces.ants.utils.AI>
# 240619-16:14:37,577 nipype.workflow INFO:
# 	 [Node] Finished "init_aff", elapsed time 9.676261s.
# 240619-16:14:38,2 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_native_wf.boldref_bold" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_native_wf/boldref_bold".
# 240619-16:14:38,5 nipype.workflow INFO:
# 	 [Node] Executing "boldref_bold" <fmriprep.interfaces.resampling.ResampleSeries>
# 240619-16:17:15,213 nipype.workflow INFO:
# 	 [Node] Finished "fsnative2t1w_xfm", elapsed time 169.027545s.
# 240619-16:18:26,597 nipype.workflow INFO:
# 	 [Node] Finished "boldref_bold", elapsed time 228.590938s.
# 240619-16:18:28,452 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_confounds_wf.dvars" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_confounds_wf/dvars".
# 240619-16:18:28,453 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.norm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/norm".
# 240619-16:18:28,456 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_confounds_wf.tcompcor" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_confounds_wf/tcompcor".
# 240619-16:18:28,458 nipype.workflow INFO:
# 	 [Node] Executing "norm" <niworkflows.interfaces.fixes.FixHeaderRegistration>
# 240619-16:18:28,511 nipype.workflow INFO:
# 	 [Node] Executing "dvars" <nipype.algorithms.confounds.ComputeDVARS>
# 240619-16:18:29,168 nipype.workflow INFO:
# 	 [Node] Executing "tcompcor" <niworkflows.interfaces.patches.RobustTCompCor>
# 240619-16:19:02,761 nipype.workflow INFO:
# 	 [Node] Finished "dvars", elapsed time 34.249095s.
# 240619-16:20:02,576 nipype.workflow INFO:
# 	 [Node] Finished "tcompcor", elapsed time 93.406737s.
# 240619-16:20:02,677 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_confounds_wf.tcc_metadata_filter" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_confounds_wf/tcc_metadata_filter".
# 240619-16:20:02,683 nipype.workflow INFO:
# 	 [Node] Executing "tcc_metadata_filter" <fmriprep.interfaces.confounds.FilterDropped>
# 240619-16:20:02,697 nipype.workflow INFO:
# 	 [Node] Finished "tcc_metadata_filter", elapsed time 0.012251s.
# 240619-16:20:04,693 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_confounds_wf.tcc_metadata_fmt" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_confounds_wf/tcc_metadata_fmt".
# 240619-16:20:05,278 nipype.workflow INFO:
# 	 [Node] Executing "tcc_metadata_fmt" <niworkflows.interfaces.utility.TSV2JSON>
# 240619-16:20:05,285 nipype.workflow INFO:
# 	 [Node] Finished "tcc_metadata_fmt", elapsed time 0.005354s.
# 240619-16:22:46,593 nipype.workflow INFO:
# 	 [Node] Finished "norm", elapsed time 258.133523s.
# 240619-16:22:47,104 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.map_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/map_brainmask".
# 240619-16:22:47,104 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.map_wmmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/map_wmmask".
# 240619-16:22:47,108 nipype.workflow INFO:
# 	 [Node] Executing "map_brainmask" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240619-16:22:47,108 nipype.workflow INFO:
# 	 [Node] Executing "map_wmmask" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240619-16:23:02,395 nipype.workflow INFO:
# 	 [Node] Finished "map_brainmask", elapsed time 15.286294s.
# 240619-16:23:02,691 nipype.workflow INFO:
# 	 [Node] Finished "map_wmmask", elapsed time 15.581976000000001s.
# 240619-16:23:03,146 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.thr_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/thr_brainmask".
# 240619-16:23:03,148 nipype.workflow INFO:
# 	 [Node] Executing "thr_brainmask" <nipype.interfaces.ants.utils.ThresholdImage>
# 240619-16:23:03,150 nipype.workflow INFO:
# 	 [Node] Setting-up "_inu_n4_final0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/inu_n4_final/mapflow/_inu_n4_final0".
# 240619-16:23:03,151 nipype.workflow INFO:
# 	 [Node] Executing "_inu_n4_final0" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 240619-16:23:03,803 nipype.workflow INFO:
# 	 [Node] Finished "thr_brainmask", elapsed time 0.653892s.
# 240619-16:23:05,124 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.03_pad_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/03_pad_mask".
# 240619-16:23:05,124 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.dil_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/dil_brainmask".
# 240619-16:23:05,126 nipype.workflow INFO:
# 	 [Node] Executing "03_pad_mask" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:05,126 nipype.workflow INFO:
# 	 [Node] Executing "dil_brainmask" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:05,508 nipype.workflow INFO:
# 	 [Node] Finished "03_pad_mask", elapsed time 0.247977s.
# 240619-16:23:05,846 nipype.workflow INFO:
# 	 [Node] Finished "dil_brainmask", elapsed time 0.718719s.
# 240619-16:23:07,138 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.get_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/get_brainmask".
# 240619-16:23:07,141 nipype.workflow INFO:
# 	 [Node] Executing "get_brainmask" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:07,900 nipype.workflow INFO:
# 	 [Node] Finished "get_brainmask", elapsed time 0.650069s.
# 240619-16:23:09,293 nipype.workflow INFO:
# 	 [Node] Finished "_inu_n4_final0", elapsed time 6.1409s.
# 240619-16:23:11,159 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.01_atropos" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/01_atropos".
# 240619-16:23:11,161 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_mask0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/apply_mask/mapflow/_apply_mask0".
# 240619-16:23:11,161 nipype.workflow INFO:
# 	 [Node] Executing "01_atropos" <nipype.interfaces.ants.segmentation.Atropos>
# 240619-16:23:11,162 nipype.workflow INFO:
# 	 [Node] Executing "_apply_mask0" <niworkflows.interfaces.nibabel.ApplyMask>
# 240619-16:23:11,346 nipype.workflow INFO:
# 	 [Node] Finished "_apply_mask0", elapsed time 0.183176s.
# 240619-16:23:35,258 nipype.workflow INFO:
# 	 [Node] Finished "01_atropos", elapsed time 24.095597s.
# 240619-16:23:37,231 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.02_pad_segm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/02_pad_segm".
# 240619-16:23:37,233 nipype.workflow INFO:
# 	 [Node] Executing "02_pad_segm" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:37,810 nipype.workflow INFO:
# 	 [Node] Finished "02_pad_segm", elapsed time 0.576003s.
# 240619-16:23:39,236 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.04_sel_labels" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/04_sel_labels".
# 240619-16:23:39,238 nipype.workflow INFO:
# 	 [Node] Executing "04_sel_labels" <nipype.interfaces.utility.wrappers.Function>
# 240619-16:23:39,655 nipype.workflow INFO:
# 	 [Node] Finished "04_sel_labels", elapsed time 0.416734s.
# 240619-16:23:41,236 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.05_get_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/05_get_wm".
# 240619-16:23:41,236 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.06_get_gm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/06_get_gm".
# 240619-16:23:41,236 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.10_me_csf" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/10_me_csf".
# 240619-16:23:41,236 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.27_depad_csf" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/27_depad_csf".
# 240619-16:23:41,238 nipype.workflow INFO:
# 	 [Node] Executing "06_get_gm" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:41,238 nipype.workflow INFO:
# 	 [Node] Executing "05_get_wm" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:41,238 nipype.workflow INFO:
# 	 [Node] Executing "10_me_csf" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:41,239 nipype.workflow INFO:
# 	 [Node] Executing "27_depad_csf" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:41,505 nipype.workflow INFO:
# 	 [Node] Finished "27_depad_csf", elapsed time 0.264398s.
# 240619-16:23:42,880 nipype.workflow INFO:
# 	 [Node] Finished "05_get_wm", elapsed time 1.640455s.
# 240619-16:23:42,882 nipype.workflow INFO:
# 	 [Node] Finished "06_get_gm", elapsed time 1.6430470000000001s.
# 240619-16:23:43,213 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.09_relabel_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/09_relabel_wm".
# 240619-16:23:43,213 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.07_fill_gm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/07_fill_gm".
# 240619-16:23:43,233 nipype.workflow INFO:
# 	 [Node] Executing "09_relabel_wm" <nipype.interfaces.ants.utils.MultiplyImages>
# 240619-16:23:43,233 nipype.workflow INFO:
# 	 [Node] Executing "07_fill_gm" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:43,630 nipype.workflow INFO:
# 	 [Node] Finished "10_me_csf", elapsed time 2.390185s.
# 240619-16:23:43,685 nipype.workflow INFO:
# 	 [Node] Finished "09_relabel_wm", elapsed time 0.451384s.
# 240619-16:23:45,208 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.26_depad_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/26_depad_wm".
# 240619-16:23:45,208 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.apply_wm_prior" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/apply_wm_prior".
# 240619-16:23:45,210 nipype.workflow INFO:
# 	 [Node] Executing "26_depad_wm" <nipype.interfaces.ants.utils.ImageMath>
# 240619-16:23:45,210 nipype.workflow INFO:
# 	 [Node] Executing "apply_wm_prior" <nipype.interfaces.utility.wrappers.Function>
# 240619-16:23:45,501 nipype.workflow INFO:
# ...
# 	 [Node] Error on "_create_wm_distvol1" (/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/anat_ribbon_wf/create_wm_distvol/mapflow/_create_wm_distvol1)
# 240620-11:11:08,963 nipype.workflow INFO:
# 	 [Node] Finished "_create_wm_distvol0", elapsed time 2.371202s.
# 240620-11:11:08,964 nipype.workflow WARNING:
# 	 [Node] Error on "_create_wm_distvol0" (/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/anat_ribbon_wf/create_wm_distvol/mapflow/_create_wm_distvol0)
# 240620-11:11:08,974 nipype.workflow INFO:
# 	 [Node] Finished "_project_unproject1", elapsed time 2.350588s.
# 240620-11:11:08,975 nipype.workflow WARNING:
# 	 [Node] Error on "_project_unproject1" (/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/fsLR_reg_wf/project_unproject/mapflow/_project_unproject1)
# 240620-11:11:10,568 nipype.workflow ERROR:
# 	 Node _create_wm_distvol0 failed to run on host Jaceks-MBP-2.
# 240620-11:11:10,568 nipype.workflow ERROR:
# 	 Saving crash info to /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/log/20240619-155842_f22409a1-275c-45ea-a261-acd3a3702756/crash-20240620-111110-jacekdmochowski-_create_wm_distvol0-c934d13c-10b6-4d66-8749-d743ab86be26.txt
# Traceback (most recent call last):
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 527, in run
#     result = self._run_interface(execute=True)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 645, in _run_interface
#     return self._run_command(execute)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 771, in _run_command
#     raise NodeExecutionError(msg)
# nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _create_wm_distvol0.
#
# Cmdline:
# 	wb_command -create-signed-distance-volume /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/gifti_surface_wf/fix_surfs/mapflow/_fix_surfs0/lh.white_converted.gii /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/copy_xform/sub-06_T1w_noise_corrected_corrected_xform.nii lh.white_converted_distvol.nii.gz -approx-limit 20.000000 -approx-neighborhood 2 -exact-limit 5.000000 -fill-value 0.000000 -roi-out lh.white_converted_distmask.nii.gz -winding EVEN_ODD
# Stdout:
#
# Stderr:
# 	/Users/jacekdmochowski/SOFTWARE/workbench/bin_macosx64/wb_command: line 14:  1979 Killed: 9               "$directory"/../macosx64_apps/wb_command.app/Contents/MacOS/wb_command "$@"
# Traceback:
# 	RuntimeError: subprocess exited with code 137.
#
# 240620-11:11:10,570 nipype.workflow ERROR:
# 	 Node _create_wm_distvol1 failed to run on host Jaceks-MBP-2.
# 240620-11:11:10,570 nipype.workflow ERROR:
# 	 Saving crash info to /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/log/20240619-155842_f22409a1-275c-45ea-a261-acd3a3702756/crash-20240620-111110-jacekdmochowski-_create_wm_distvol1-8facac29-97cd-4283-ac68-6234d4b75686.txt
# Traceback (most recent call last):
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 527, in run
#     result = self._run_interface(execute=True)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 645, in _run_interface
#     return self._run_command(execute)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 771, in _run_command
#     raise NodeExecutionError(msg)
# nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _create_wm_distvol1.
#
# Cmdline:
# 	wb_command -create-signed-distance-volume /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/gifti_surface_wf/fix_surfs/mapflow/_fix_surfs1/rh.white_converted.gii /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/copy_xform/sub-06_T1w_noise_corrected_corrected_xform.nii rh.white_converted_distvol.nii.gz -approx-limit 20.000000 -approx-neighborhood 2 -exact-limit 5.000000 -fill-value 0.000000 -roi-out rh.white_converted_distmask.nii.gz -winding EVEN_ODD
# Stdout:
#
# Stderr:
# 	/Users/jacekdmochowski/SOFTWARE/workbench/bin_macosx64/wb_command: line 14:  1980 Killed: 9               "$directory"/../macosx64_apps/wb_command.app/Contents/MacOS/wb_command "$@"
# Traceback:
# 	RuntimeError: subprocess exited with code 137.
#
# 240620-11:11:10,571 nipype.workflow ERROR:
# 	 Node _create_pial_distvol0 failed to run on host Jaceks-MBP-2.
# 240620-11:11:10,571 nipype.workflow ERROR:
# 	 Saving crash info to /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/log/20240619-155842_f22409a1-275c-45ea-a261-acd3a3702756/crash-20240620-111110-jacekdmochowski-_create_pial_distvol0-43495cdc-5aa5-4fa3-aea9-689432478900.txt
# Traceback (most recent call last):
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 527, in run
#     result = self._run_interface(execute=True)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 645, in _run_interface
#     return self._run_command(execute)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 771, in _run_command
#     raise NodeExecutionError(msg)
# nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _create_pial_distvol0.
#
# Cmdline:
# 	wb_command -create-signed-distance-volume /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/gifti_surface_wf/fix_surfs/mapflow/_fix_surfs2/lh.pial_converted.gii /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/copy_xform/sub-06_T1w_noise_corrected_corrected_xform.nii lh.pial_converted_distvol.nii.gz -approx-limit 20.000000 -approx-neighborhood 2 -exact-limit 5.000000 -fill-value 0.000000 -roi-out lh.pial_converted_distmask.nii.gz -winding EVEN_ODD
# Stdout:
#
# Stderr:
# 	/Users/jacekdmochowski/SOFTWARE/workbench/bin_macosx64/wb_command: line 14:  1975 Killed: 9               "$directory"/../macosx64_apps/wb_command.app/Contents/MacOS/wb_command "$@"
# Traceback:
# 	RuntimeError: subprocess exited with code 137.
#
# 240620-11:11:10,572 nipype.workflow ERROR:
# 	 Node _create_pial_distvol1 failed to run on host Jaceks-MBP-2.
# 240620-11:11:10,572 nipype.workflow ERROR:
# 	 Saving crash info to /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/log/20240619-155842_f22409a1-275c-45ea-a261-acd3a3702756/crash-20240620-111110-jacekdmochowski-_create_pial_distvol1-71ab0f3e-870d-4e06-8ae7-b96c8fd97e8d.txt
# Traceback (most recent call last):
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 527, in run
#     result = self._run_interface(execute=True)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 645, in _run_interface
#     return self._run_command(execute)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 771, in _run_command
#     raise NodeExecutionError(msg)
# nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _create_pial_distvol1.
#
# Cmdline:
# 	wb_command -create-signed-distance-volume /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/gifti_surface_wf/fix_surfs/mapflow/_fix_surfs3/rh.pial_converted.gii /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/copy_xform/sub-06_T1w_noise_corrected_corrected_xform.nii rh.pial_converted_distvol.nii.gz -approx-limit 20.000000 -approx-neighborhood 2 -exact-limit 5.000000 -fill-value 0.000000 -roi-out rh.pial_converted_distmask.nii.gz -winding EVEN_ODD
# Stdout:
#
# Stderr:
# 	/Users/jacekdmochowski/SOFTWARE/workbench/bin_macosx64/wb_command: line 14:  1976 Killed: 9               "$directory"/../macosx64_apps/wb_command.app/Contents/MacOS/wb_command "$@"
# Traceback:
# 	RuntimeError: subprocess exited with code 137.
#
# 240620-11:11:10,573 nipype.workflow ERROR:
# 	 Node _project_unproject0 failed to run on host Jaceks-MBP-2.
# 240620-11:11:10,573 nipype.workflow ERROR:
# 	 Saving crash info to /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/log/20240619-155842_f22409a1-275c-45ea-a261-acd3a3702756/crash-20240620-111110-jacekdmochowski-_project_unproject0-6a32abb9-2d6d-4cd5-b6f7-adc33436fd8f.txt
# Traceback (most recent call last):
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 527, in run
#     result = self._run_interface(execute=True)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 645, in _run_interface
#     return self._run_command(execute)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 771, in _run_command
#     raise NodeExecutionError(msg)
# nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _project_unproject0.
#
# Cmdline:
# 	wb_command -surface-sphere-project-unproject /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/gifti_spheres_wf/fix_surfs/mapflow/_fix_surfs0/lh.sphere.reg_converted.gii /Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/smriprep/data/atlases/fs_L/fsaverage.L.sphere.164k_fs_L.surf.gii /Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/smriprep/data/atlases/fs_L/fs_L-to-fs_LR_fsaverage.L_LR.spherical_std.164k_fs_L.surf.gii lh.sphere.reg_converted_unprojected.surf.gii
# Stdout:
#
# Stderr:
# 	/Users/jacekdmochowski/SOFTWARE/workbench/bin_macosx64/wb_command: line 14:  1983 Killed: 9               "$directory"/../macosx64_apps/wb_command.app/Contents/MacOS/wb_command "$@"
# Traceback:
# 	RuntimeError: subprocess exited with code 137.
#
# 240620-11:11:10,574 nipype.workflow ERROR:
# 	 Node _project_unproject1 failed to run on host Jaceks-MBP-2.
# 240620-11:11:10,574 nipype.workflow ERROR:
# 	 Saving crash info to /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-06/log/20240619-155842_f22409a1-275c-45ea-a261-acd3a3702756/crash-20240620-111110-jacekdmochowski-_project_unproject1-08dada12-1590-4bd7-9f29-09576d3c544e.txt
# Traceback (most recent call last):
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node
#     result["result"] = node.run(updatehash=updatehash)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 527, in run
#     result = self._run_interface(execute=True)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 645, in _run_interface
#     return self._run_command(execute)
#   File "/Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/nipype/pipeline/engine/nodes.py", line 771, in _run_command
#     raise NodeExecutionError(msg)
# nipype.pipeline.engine.nodes.NodeExecutionError: Exception raised while executing Node _project_unproject1.
#
# Cmdline:
# 	wb_command -surface-sphere-project-unproject /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/anat_fit_wf/gifti_spheres_wf/fix_surfs/mapflow/_fix_surfs1/rh.sphere.reg_converted.gii /Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/smriprep/data/atlases/fs_R/fsaverage.R.sphere.164k_fs_R.surf.gii /Users/jacekdmochowski/miniconda3/envs/fus/lib/python3.10/site-packages/smriprep/data/atlases/fs_R/fs_R-to-fs_LR_fsaverage.R_LR.spherical_std.164k_fs_R.surf.gii rh.sphere.reg_converted_unprojected.surf.gii
# Stdout:
#
# Stderr:
# 	/Users/jacekdmochowski/SOFTWARE/workbench/bin_macosx64/wb_command: line 14:  1985 Killed: 9               "$directory"/../macosx64_apps/wb_command.app/Contents/MacOS/wb_command "$@"
# Traceback:
# 	RuntimeError: subprocess exited with code 137.
#
# 240620-11:11:10,664 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_anat_wf.resample" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_anat_wf/resample".
# 240620-11:11:10,668 nipype.workflow INFO:
# 	 [Node] Executing "resample" <fmriprep.interfaces.resampling.ResampleSeries>
# 240620-11:13:13,683 nipype.workflow INFO:
# 	 [Node] Finished "resample", elapsed time 123.014231s.
# 240620-11:13:14,976 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.bold_std_wf.resample" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/bold_std_wf/_in_tuple_MNI152NLin2009cAsym.resnative/resample".
# 240620-11:13:14,979 nipype.workflow INFO:
# 	 [Node] Executing "resample" <fmriprep.interfaces.resampling.ResampleSeries>
# 240620-11:15:49,853 nipype.workflow INFO:
# 	 [Node] Finished "resample", elapsed time 154.873436s.
# 240620-11:15:51,385 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_24_0_wf.sub_06_wf.bold_task_prefuspost_wf.ds_bold_std_wf.ds_bold" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_24_0_wf/sub_06_wf/bold_task_prefuspost_wf/ds_bold_std_wf/_in_tuple_MNI152NLin2009cAsym.resnative/ds_bold".
# 240620-11:15:51,399 nipype.workflow INFO:
# 	 [Node] Executing "ds_bold" <fmriprep.interfaces.DerivativesDataSink>
# 240620-11:17:15,263 nipype.workflow INFO:
# 	 [Node] Finished "ds_bold", elapsed time 83.863265s.
# 240620-11:17:17,482 nipype.workflow ERROR:
# 	 could not run node: fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.anat_ribbon_wf.create_wm_distvol
# 240620-11:17:17,482 nipype.workflow ERROR:
# 	 could not run node: fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.anat_ribbon_wf.create_wm_distvol
# 240620-11:17:17,482 nipype.workflow ERROR:
# 	 could not run node: fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.anat_ribbon_wf.create_pial_distvol
# 240620-11:17:17,482 nipype.workflow ERROR:
# 	 could not run node: fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.anat_ribbon_wf.create_pial_distvol
# 240620-11:17:17,482 nipype.workflow ERROR:
# 	 could not run node: fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.fsLR_reg_wf.project_unproject
# 240620-11:17:17,482 nipype.workflow ERROR:
# 	 could not run node: fmriprep_24_0_wf.sub_06_wf.anat_fit_wf.fsLR_reg_wf.project_unproject
# 240620-11:17:17,647 nipype.workflow CRITICAL:
# 	 fMRIPrep failed: 6 raised. Re-raising first.
