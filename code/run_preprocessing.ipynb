# %%
## Script that will run the raw data through our preprocessing pipeline

# %%
import os
import subprocess

# %%
subject_idx = 3

# %%
# make a sub-xx directory in ~/PROJECTS/fus/data/fmriprep_out
if not os.path.exists(f'/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-{subject_idx:02d}'):
    os.makedirs(f'/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-{subject_idx:02d}')

# %%
fmriprep_call = f"fmriprep /Users/jacekdmochowski/PROJECTS/fus/data/bold /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out participant -w /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working --fs-license-file ~/license.txt --mem 64000000000 --nprocs 10 --participant-label {subject_idx:02d}"

# %%
print(fmriprep_call)
# Out:
# fmriprep /Users/jacekdmochowski/PROJECTS/fus/data/bold /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out participant -w /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working --fs-license-file ~/license.txt --mem 64000000000 --nprocs 10 --participant-label 03

# %%
return_code = subprocess.call([fmriprep_call], shell=True)
# Out:
# bids-validator@1.14.4
# 	1: [WARN] The recommended file /README is missing. See Section 03 (Modality agnostic files) of the BIDS specification. (code: 101 - README_FILE_MISSING)
#
# 	Please visit https://neurostars.org/search?q=README_FILE_MISSING for existing conversations about this issue.
#
#         Summary:                Available Tasks:        Available Modalities:
#         20 Files, 3.19GB                                MRI
#         3 - Subjects
#         1 - Session
#
#
# 	If you have any questions, please post on https://neurostars.org/tags/bids.
# (node:30187) [DEP0040] DeprecationWarning: The `punycode` module is deprecated. Please use a userland alternative instead.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# (node:30187) Warning: Closing directory handle on garbage collection
# 240410-23:51:17,888 nipype.workflow IMPORTANT:
# 	 Running fMRIPrep version 23.2.1
#
#          License NOTICE ##################################################
#          fMRIPrep 23.2.1
#          Copyright 2023 The NiPreps Developers.
#
#          This product includes software developed by
#          the NiPreps Community (https://nipreps.org/).
#
#          Portions of this software were developed at the Department of
#          Psychology at Stanford University, Stanford, CA, US.
#
#          This software is also distributed as a Docker container image.
#          The bootstrapping file for the image ("Dockerfile") is licensed
#          under the MIT License.
#
#          This software may be distributed through an add-on package called
#          "Docker Wrapper" that is under the BSD 3-clause License.
#          #################################################################
# 240410-23:51:17,900 nipype.workflow IMPORTANT:
# 	 Building fMRIPrep's workflow:
#            * BIDS dataset path: /Users/jacekdmochowski/PROJECTS/fus/data/bold.
#            * Participant list: ['03'].
#            * Run identifier: 20240410-235110_1fe2c0af-81d4-4765-a035-be5f47cd8db9.
#            * Output spaces: MNI152NLin2009cAsym:res-native.
#            * Pre-run FreeSurfer's SUBJECTS_DIR: /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sourcedata/freesurfer.
# 240410-23:51:18,96 nipype.workflow INFO:
# 	 ANAT Stage 1: Adding template workflow
# 240410-23:51:18,257 nipype.workflow INFO:
# 	 ANAT Stage 2: Preparing brain extraction workflow
# 240410-23:51:18,310 nipype.workflow INFO:
# 	 ANAT Stage 3: Preparing segmentation workflow
# 240410-23:51:18,313 nipype.workflow INFO:
# 	 ANAT Stage 4: Preparing normalization workflow for ['MNI152NLin2009cAsym']
# 240410-23:51:18,318 nipype.workflow INFO:
# 	 ANAT Stage 5: Preparing surface reconstruction workflow
# 240410-23:51:18,330 nipype.workflow INFO:
# 	 ANAT Stage 6: Preparing mask refinement workflow
# 240410-23:51:18,331 nipype.workflow INFO:
# 	 ANAT No T2w images provided - skipping Stage 7
# 240410-23:51:18,332 nipype.workflow INFO:
# 	 ANAT Stage 8: Creating GIFTI surfaces for ['white', 'pial', 'midthickness', 'sphere_reg', 'sphere']
# 240410-23:51:18,341 nipype.workflow INFO:
# 	 ANAT Stage 8: Creating GIFTI metrics for ['thickness', 'sulc']
# 240410-23:51:18,345 nipype.workflow INFO:
# 	 ANAT Stage 8a: Creating cortical ribbon mask
# 240410-23:51:18,347 nipype.workflow INFO:
# 	 ANAT Stage 9: Creating fsLR registration sphere
# 240410-23:51:18,349 nipype.workflow INFO:
# 	 ANAT Stage 10: Creating MSM-Sulc registration sphere
# 240410-23:51:18,467 nipype.workflow INFO:
# 	 No single-band-reference found for sub-03_task-prefuspost_bold.nii.gz.
# 240410-23:51:18,507 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240410-23:51:18,511 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240410-23:51:18,516 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240410-23:51:18,919 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.435s.
# 240410-23:51:20,703 nipype.workflow INFO:
# 	 fMRIPrep workflow graph with 392 nodes built successfully.
# 240410-23:51:28,514 nipype.workflow IMPORTANT:
# 	 fMRIPrep started!
# 240410-23:51:31,558 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.full_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/full_wm".
# 240410-23:51:31,561 nipype.workflow INFO:
# 	 [Node] Executing "full_wm" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:51:31,614 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/lap_tmpl".
# 240410-23:51:31,620 nipype.workflow INFO:
# 	 [Node] Executing "lap_tmpl" <nipype.interfaces.ants.utils.ImageMath>
# 240410-23:51:31,634 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.res_tmpl" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/res_tmpl".
# 240410-23:51:31,636 nipype.workflow INFO:
# 	 [Node] Executing "res_tmpl" <niworkflows.interfaces.nibabel.RegridToZooms>
# 240410-23:51:31,664 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_hmc_boldref_wf/raw_sources".
# 240410-23:51:31,666 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:51:31,710 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_hmc_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_hmc_wf/raw_sources".
# 240410-23:51:31,712 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:51:31,752 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000846s.
# 240410-23:51:31,754 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.ds_bold_std_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/ds_bold_std_wf/raw_sources".
# 240410-23:51:31,756 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:51:31,755 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_native_wf.bold_source" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_native_wf/bold_source".
# 240410-23:51:31,756 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000184s.
# 240410-23:51:31,756 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000836s.
# 240410-23:51:31,898 nipype.workflow INFO:
# 	 [Node] Executing "bold_source" <nipype.interfaces.utility.base.Select>
# 240410-23:51:31,928 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.hmc_boldref_wf.val_bold" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/val_bold".
# 240410-23:51:31,932 nipype.workflow INFO:
# 	 [Node] Executing "val_bold" <niworkflows.interfaces.header.ValidateImage>
# 240410-23:51:31,954 nipype.workflow INFO:
# 	 [Node] Finished "bold_source", elapsed time 0.00058s.
# 240410-23:51:32,10 nipype.workflow INFO:
# 	 [Node] Finished "full_wm", elapsed time 0.389873s.
# 240410-23:51:32,16 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.hmc_boldref_wf.get_dummy" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/get_dummy".
# 240410-23:51:32,17 nipype.workflow INFO:
# 	 [Node] Executing "get_dummy" <niworkflows.interfaces.bold.NonsteadyStatesDetector>
# 240410-23:51:32,553 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bidssrc" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bidssrc".
# 240410-23:51:32,554 nipype.workflow INFO:
# 	 [Node] Executing "bidssrc" <niworkflows.interfaces.bids.BIDSDataGrabber>
# 240410-23:51:32,565 nipype.interface INFO:
# 	 No "t2w" images found for sub-03
# 240410-23:51:32,566 nipype.interface INFO:
# 	 No "flair" images found for sub-03
# 240410-23:51:32,566 nipype.interface INFO:
# 	 No "fmap" images found for sub-03
# 240410-23:51:32,566 nipype.interface INFO:
# 	 No "sbref" images found for sub-03
# 240410-23:51:32,566 nipype.interface INFO:
# 	 No "roi" images found for sub-03
# 240410-23:51:32,566 nipype.interface INFO:
# 	 No "pet" images found for sub-03
# 240410-23:51:32,567 nipype.interface INFO:
# 	 No "asl" images found for sub-03
# 240410-23:51:32,568 nipype.workflow INFO:
# 	 [Node] Finished "bidssrc", elapsed time 0.002088s.
# 240410-23:51:32,838 nipype.workflow INFO:
# 	 [Node] Finished "res_tmpl", elapsed time 1.171921s.
# 240410-23:51:33,145 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.anat_template_wf.anat_ref_dimensions" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/anat_template_wf/anat_ref_dimensions".
# 240410-23:51:33,249 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_native_wf.validate_bold" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_native_wf/validate_bold".
# 240410-23:51:33,251 nipype.workflow INFO:
# 	 [Node] Executing "validate_bold" <niworkflows.interfaces.header.ValidateImage>
# 240410-23:51:33,775 nipype.workflow INFO:
# 	 [Node] Executing "anat_ref_dimensions" <niworkflows.interfaces.images.TemplateDimensions>
# 240410-23:51:33,783 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bids_info" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bids_info".
# 240410-23:51:33,784 nipype.workflow INFO:
# 	 [Node] Executing "bids_info" <niworkflows.interfaces.bids.BIDSInfo>
# 240410-23:51:33,788 nipype.workflow INFO:
# 	 [Node] Finished "bids_info", elapsed time 0.002664s.
# 240410-23:51:33,849 nipype.workflow INFO:
# 	 [Node] Finished "anat_ref_dimensions", elapsed time 0.073158s.
# 240410-23:51:35,594 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.fs_isrunning" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/fs_isrunning".
# 240410-23:51:35,595 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.ds_t1w_mask_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/ds_t1w_mask_wf/raw_sources".
# 240410-23:51:35,595 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.ds_ribbon_mask_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/ds_ribbon_mask_wf/raw_sources".
# 240410-23:51:35,599 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:51:35,600 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000233s.
# 240410-23:51:35,638 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:51:35,639 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000207s.
# 240410-23:51:36,197 nipype.workflow INFO:
# 	 [Node] Executing "fs_isrunning" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:51:36,209 nipype.workflow INFO:
# 	 [Node] Finished "fs_isrunning", elapsed time 0.001016s.
# 240410-23:51:36,292 nipype.workflow INFO:
# 	 [Node] Finished "lap_tmpl", elapsed time 4.397234s.
# 240410-23:51:36,805 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.mrg_tmpl" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/mrg_tmpl".
# 240410-23:51:36,819 nipype.workflow INFO:
# 	 [Node] Executing "mrg_tmpl" <nipype.interfaces.utility.base.Merge>
# 240410-23:51:36,820 nipype.workflow INFO:
# 	 [Node] Finished "mrg_tmpl", elapsed time 0.000106s.
# 240410-23:51:38,857 nipype.workflow INFO:
# 	 [Node] Finished "get_dummy", elapsed time 6.775357s.
# 240410-23:51:40,913 nipype.workflow INFO:
# 	 [Node] Setting-up "_denoise0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/anat_template_wf/denoise/mapflow/_denoise0".
# 240410-23:51:40,914 nipype.workflow INFO:
# 	 [Node] Executing "_denoise0" <nipype.interfaces.ants.segmentation.DenoiseImage>
# 240410-23:52:07,660 nipype.workflow INFO:
# 	 [Node] Finished "validate_bold", elapsed time 34.408176s.
# 240410-23:52:10,132 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_native_wf.bold_stc_wf.slice_timing_correction" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_native_wf/bold_stc_wf/slice_timing_correction".
# 240410-23:52:10,137 nipype.workflow INFO:
# 	 [Node] Executing "slice_timing_correction" <fmriprep.workflows.bold.stc.TShift>
# 240410-23:52:11,301 nipype.workflow INFO:
# 	 [Node] Finished "val_bold", elapsed time 39.307968s.
# 240410-23:52:12,985 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.hmc_boldref_wf.gen_avg" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/gen_avg".
# 240410-23:52:12,997 nipype.workflow INFO:
# 	 [Node] Executing "gen_avg" <niworkflows.interfaces.images.RobustAverage>
# 240410-23:52:19,874 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.873506:++ 3dvolreg: AFNI version=AFNI_22.3.03 (Oct 13 2022) [64-bit]
# 240410-23:52:19,874 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.873506:++ Authored by: RW Cox
# 240410-23:52:19,883 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.881349:** AFNI converts NIFTI_datatype=512 (UINT16) in file /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/gen_avg/sub-03_task-prefuspost_bold_valid_sliced.nii.gz to FLOAT32
# 240410-23:52:19,883 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.881349:     Warnings of this type will be muted for this session.
# 240410-23:52:19,884 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.881349:     Set AFNI_NIFTI_TYPE_WARN to YES to see them all, NO to see none.
# 240410-23:52:19,897 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.896972:*+ WARNING:   If you are performing spatial transformations on an oblique dset,
# 240410-23:52:19,898 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.896972:  such as /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/gen_avg/sub-03_task-prefuspost_bold_valid_sliced.nii.gz,
# 240410-23:52:19,898 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.896972:  or viewing/combining it with volumes of differing obliquity,
# 240410-23:52:19,898 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.896972:  you should consider running:
# 240410-23:52:19,898 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.896972:     3dWarp -deoblique
# 240410-23:52:19,898 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.896972:  on this and  other oblique datasets in the same session.
# 240410-23:52:19,898 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.896972: See 3dWarp -help for details.
# 240410-23:52:19,898 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.896972:++ Oblique dataset:/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/hmc_boldref_wf/gen_avg/sub-03_task-prefuspost_bold_valid_sliced.nii.gz is 20.432878 degrees from plumb.
# 240410-23:52:19,899 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:19.898973:++ Coarse del was 10, replaced with 7
# 240410-23:52:25,167 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:25.166882:++ Max displacement in automask = 0.08 (mm) at sub-brick 1
# 240410-23:52:25,167 nipype.interface INFO:
# 	 stderr 2024-04-10T23:52:25.166882:++ Max delta displ  in automask = 0.08 (mm) at sub-brick 1
# 240410-23:52:25,719 nipype.workflow INFO:
# 	 [Node] Finished "gen_avg", elapsed time 12.721246s.
# 240410-23:52:26,933 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.fmapref_buffer" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/fmapref_buffer".
# 240410-23:52:26,935 nipype.workflow INFO:
# 	 [Node] Executing "fmapref_buffer" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:52:26,936 nipype.workflow INFO:
# 	 [Node] Finished "fmapref_buffer", elapsed time 0.000408s.
# 240410-23:52:28,957 nipype.interface WARNING:
# 	 Changing /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-03/func/sub-03_task-prefuspost_desc-hmc_boldref.nii.gz dtype from uint16 to float32
# 240410-23:52:29,235 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.bold_hmc_wf.mcflirt" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/bold_hmc_wf/mcflirt".
# 240410-23:52:29,241 nipype.workflow INFO:
# 	 [Node] Executing "mcflirt" <nipype.interfaces.fsl.preprocess.MCFLIRT>
# 240410-23:52:35,628 nipype.workflow INFO:
# 	 [Node] Finished "_denoise0", elapsed time 54.617489s.
# 240410-23:52:36,931 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_coreg_boldref_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_coreg_boldref_wf/raw_sources".
# 240410-23:52:36,932 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:52:36,933 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000218s.
# 240410-23:52:36,970 nipype.workflow INFO:
# 	 [Node] Setting-up "_anat_conform0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/anat_template_wf/anat_conform/mapflow/_anat_conform0".
# 240410-23:52:36,971 nipype.workflow INFO:
# 	 [Node] Executing "_anat_conform0" <niworkflows.interfaces.images.Conform>
# 240410-23:52:37,4 nipype.workflow INFO:
# 	 [Node] Finished "_anat_conform0", elapsed time 0.032529s.
# 240410-23:52:38,955 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.init_aff" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/init_aff".
# 240410-23:52:38,957 nipype.workflow INFO:
# 	 [Node] Executing "init_aff" <nipype.interfaces.ants.utils.AI>
# 240410-23:52:58,24 nipype.workflow INFO:
# 	 [Node] Finished "init_aff", elapsed time 19.004888s.
# 240410-23:52:58,984 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.anat_template_wf.get1st" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/anat_template_wf/get1st".
# 240410-23:52:58,987 nipype.workflow INFO:
# 	 [Node] Executing "get1st" <nipype.interfaces.utility.base.Select>
# 240410-23:52:58,988 nipype.workflow INFO:
# 	 [Node] Finished "get1st", elapsed time 0.000113s.
# 240410-23:53:00,998 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.norm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/norm".
# 240410-23:53:01,1 nipype.workflow INFO:
# 	 [Node] Executing "norm" <niworkflows.interfaces.fixes.FixHeaderRegistration>
# 240410-23:53:01,470 nipype.workflow INFO:
# 	 [Node] Finished "norm", elapsed time 0.414175s.
# 240410-23:53:03,118 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.map_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/map_brainmask".
# 240410-23:53:03,120 nipype.workflow INFO:
# 	 [Node] Executing "map_brainmask" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240410-23:53:03,398 nipype.workflow INFO:
# 	 [Node] Finished "map_brainmask", elapsed time 0.196721s.
# 240410-23:53:04,994 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.surface_recon_wf.fov_check" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/surface_recon_wf/fov_check".
# 240410-23:53:04,997 nipype.workflow INFO:
# 	 [Node] Executing "fov_check" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:53:05,5 nipype.workflow INFO:
# 	 [Node] Setting-up "_truncate_images0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/truncate_images/mapflow/_truncate_images0".
# 240410-23:53:05,7 nipype.workflow INFO:
# 	 [Node] Executing "_truncate_images0" <nipype.interfaces.ants.utils.ImageMath>
# 240410-23:53:05,336 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.surface_recon_wf.recon_config" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/surface_recon_wf/recon_config".
# 240410-23:53:05,340 nipype.workflow INFO:
# 	 [Node] Executing "recon_config" <niworkflows.interfaces.freesurfer.FSDetectInputs>
# 240410-23:53:05,375 nipype.workflow INFO:
# 	 [Node] Finished "recon_config", elapsed time 0.033799s.
# 240410-23:53:05,406 nipype.workflow INFO:
# 	 [Node] Finished "fov_check", elapsed time 0.408299s.
# 240410-23:53:06,992 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.n4_correct" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/n4_correct".
# 240410-23:53:06,996 nipype.workflow INFO:
# 	 [Node] Executing "n4_correct" <niworkflows.interfaces.fixes.FixN4BiasFieldCorrection>
# 240410-23:53:08,827 nipype.workflow INFO:
# 	 [Node] Finished "n4_correct", elapsed time 1.830107s.
# 240410-23:53:09,24 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.skullstrip_first_pass" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/skullstrip_first_pass".
# 240410-23:53:09,27 nipype.workflow INFO:
# 	 [Node] Executing "skullstrip_first_pass" <nipype.interfaces.fsl.preprocess.BET>
# 240410-23:53:09,29 nipype.interface WARNING:
# 	 Changing /Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-03/func/sub-03_task-prefuspost_desc-coreg_boldref.nii.gz dtype from uint16 to float32
# 240410-23:53:10,2 nipype.workflow INFO:
# 	 [Node] Finished "skullstrip_first_pass", elapsed time 0.974261s.
# 240410-23:53:10,3 nipype.workflow INFO:
# 	 [Node] Finished "_truncate_images0", elapsed time 4.934473s.
# 240410-23:53:11,14 nipype.workflow INFO:
# 	 [Node] Setting-up "_inu_n40" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/inu_n4/mapflow/_inu_n40".
# 240410-23:53:11,15 nipype.workflow INFO:
# 	 [Node] Executing "_inu_n40" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 240410-23:53:26,742 nipype.workflow INFO:
# 	 [Node] Finished "_inu_n40", elapsed time 15.670133s.
# 240410-23:53:27,887 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.surface_recon_wf.autorecon1" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/surface_recon_wf/autorecon1".
# 240410-23:53:27,890 nipype.workflow INFO:
# 	 [Node] Executing "autorecon1" <smriprep.interfaces.freesurfer.ReconAll>
# 240410-23:54:40,739 nipype.workflow INFO:
# 	 [Node] Finished "slice_timing_correction", elapsed time 150.601528s.
# 240410-23:54:41,197 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_native_wf.bold_stc_wf.copy_xform" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_native_wf/bold_stc_wf/copy_xform".
# 240410-23:54:42,225 nipype.workflow INFO:
# 	 [Node] Executing "copy_xform" <niworkflows.interfaces.header.CopyXForm>
# 240410-23:56:03,348 nipype.workflow INFO:
# 	 [Node] Finished "copy_xform", elapsed time 81.122133s.
# 240410-23:56:05,372 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.res_target" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/res_target".
# 240410-23:56:05,374 nipype.workflow INFO:
# 	 [Node] Executing "res_target" <niworkflows.interfaces.nibabel.RegridToZooms>
# 240410-23:56:06,666 nipype.workflow INFO:
# 	 [Node] Finished "res_target", elapsed time 1.291476s.
# 240410-23:56:07,373 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.lap_target" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/lap_target".
# 240410-23:56:07,376 nipype.workflow INFO:
# 	 [Node] Executing "lap_target" <nipype.interfaces.ants.utils.ImageMath>
# 240410-23:56:13,903 nipype.workflow INFO:
# 	 [Node] Finished "lap_target", elapsed time 6.464884s.
# 240410-23:56:15,383 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.mrg_target" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/mrg_target".
# 240410-23:56:15,385 nipype.workflow INFO:
# 	 [Node] Executing "mrg_target" <nipype.interfaces.utility.base.Merge>
# 240410-23:56:15,386 nipype.workflow INFO:
# 	 [Node] Finished "mrg_target", elapsed time 9e-05s.
# 240410-23:56:17,385 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.first_dilate" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/first_dilate".
# 240410-23:56:17,387 nipype.workflow INFO:
# 	 [Node] Executing "first_dilate" <niworkflows.interfaces.nibabel.BinaryDilation>
# 240410-23:56:17,877 nipype.workflow INFO:
# 	 [Node] Finished "first_dilate", elapsed time 0.4896s.
# 240410-23:56:19,388 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.ds_boldreg_wf.raw_sources" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/ds_boldreg_wf/raw_sources".
# 240410-23:56:19,883 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240410-23:56:19,884 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000228s.
# 240410-23:56:21,396 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_std_wf.gen_ref" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_std_wf/_in_tuple_MNI152NLin2009cAsym.resnative/gen_ref".
# 240410-23:56:21,879 nipype.workflow INFO:
# 	 [Node] Executing "gen_ref" <niworkflows.interfaces.nibabel.GenerateSamplingReference>
# 240410-23:56:23,529 nipype.workflow INFO:
# 	 [Node] Finished "gen_ref", elapsed time 1.649694s.
# 240410-23:56:25,399 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.first_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/first_mask".
# 240410-23:56:25,401 nipype.workflow INFO:
# 	 [Node] Executing "first_mask" <niworkflows.interfaces.nibabel.ApplyMask>
# 240410-23:56:25,443 nipype.workflow INFO:
# 	 [Node] Finished "first_mask", elapsed time 0.041484s.
# 240410-23:56:27,405 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.unifize" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/unifize".
# 240410-23:56:27,408 nipype.workflow INFO:
# 	 [Node] Executing "unifize" <nipype.interfaces.afni.utils.Unifize>
# 240410-23:57:22,389 nipype.workflow INFO:
# 	 [Node] Finished "unifize", elapsed time 54.979857s.
# 240410-23:57:23,513 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.fixhdr_unifize" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/fixhdr_unifize".
# 240410-23:57:23,534 nipype.workflow INFO:
# 	 [Node] Executing "fixhdr_unifize" <niworkflows.interfaces.header.CopyXForm>
# 240410-23:57:23,581 nipype.workflow INFO:
# 	 [Node] Finished "fixhdr_unifize", elapsed time 0.046306s.
# 240410-23:57:25,540 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.skullstrip_second_pass" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/skullstrip_second_pass".
# 240410-23:57:25,542 nipype.workflow INFO:
# 	 [Node] Executing "skullstrip_second_pass" <nipype.interfaces.afni.preprocess.Automask>
# 240410-23:57:25,841 nipype.workflow INFO:
# 	 [Node] Finished "skullstrip_second_pass", elapsed time 0.298252s.
# 240410-23:57:27,524 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.fixhdr_skullstrip2" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/fixhdr_skullstrip2".
# 240410-23:57:27,541 nipype.workflow INFO:
# 	 [Node] Executing "fixhdr_skullstrip2" <niworkflows.interfaces.header.CopyXForm>
# 240410-23:57:27,560 nipype.workflow INFO:
# 	 [Node] Finished "fixhdr_skullstrip2", elapsed time 0.018007s.
# 240410-23:57:29,527 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.combine_masks" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/combine_masks".
# 240410-23:57:29,533 nipype.workflow INFO:
# 	 [Node] Executing "combine_masks" <nipype.interfaces.fsl.maths.BinaryMaths>
# 240410-23:57:29,627 nipype.workflow INFO:
# 	 [Node] Finished "combine_masks", elapsed time 0.093518s.
# 240410-23:57:31,529 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.enhance_and_skullstrip_bold_wf.apply_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/enhance_and_skullstrip_bold_wf/apply_mask".
# 240410-23:57:31,616 nipype.workflow INFO:
# 	 [Node] Executing "apply_mask" <niworkflows.interfaces.nibabel.ApplyMask>
# 240410-23:57:31,657 nipype.workflow INFO:
# 	 [Node] Finished "apply_mask", elapsed time 0.040273s.
# 240410-23:58:35,268 nipype.workflow INFO:
# 	 [Node] Finished "mcflirt", elapsed time 366.025941s.
# 240410-23:58:35,638 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.bold_hmc_wf.normalize_motion" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/bold_hmc_wf/normalize_motion".
# 240410-23:58:35,690 nipype.workflow INFO:
# 	 [Node] Executing "normalize_motion" <niworkflows.interfaces.confounds.NormalizeMotionParams>
# 240410-23:58:35,695 nipype.workflow INFO:
# 	 [Node] Finished "normalize_motion", elapsed time 0.004352s.
# 240410-23:58:37,643 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.fdisp" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/fdisp".
# 240410-23:58:37,646 nipype.workflow INFO:
# 	 [Node] Executing "fdisp" <nipype.algorithms.confounds.FramewiseDisplacement>
# 240410-23:58:37,650 nipype.workflow INFO:
# 	 [Node] Finished "fdisp", elapsed time 0.003153s.
# 240411-00:08:50,840 nipype.workflow INFO:
# 	 [Node] Finished "autorecon1", elapsed time 922.948603s.
# 240411-00:08:50,973 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.surface_recon_wf.fsnative2t1w_xfm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/surface_recon_wf/fsnative2t1w_xfm".
# 240411-00:08:50,976 nipype.workflow INFO:
# 	 [Node] Executing "fsnative2t1w_xfm" <niworkflows.interfaces.freesurfer.PatchedRobustRegister>
# 240411-00:08:50,996 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.bold_hmc_wf.fsl2itk" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/bold_hmc_wf/fsl2itk".
# 240411-00:08:51,65 nipype.workflow INFO:
# 	 [Node] Executing "fsl2itk" <niworkflows.interfaces.itk.MCFLIRT2ITK>
# 240411-00:08:51,66 nipype.interface WARNING:
# 	 Multithreading is deprecated. Remove the num_threads input.
# 240411-00:08:51,472 nipype.workflow INFO:
# 	 [Node] Finished "fsl2itk", elapsed time 0.40605s.
# 240411-00:08:53,76 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.init_aff" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/init_aff".
# 240411-00:08:53,78 nipype.workflow INFO:
# 	 [Node] Executing "init_aff" <nipype.interfaces.ants.utils.AI>
# 240411-00:09:02,592 nipype.workflow INFO:
# 	 [Node] Finished "init_aff", elapsed time 9.512715s.
# 240411-00:09:03,650 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_native_wf.boldref_bold" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_native_wf/boldref_bold".
# 240411-00:09:03,659 nipype.workflow INFO:
# 	 [Node] Executing "boldref_bold" <fmriprep.interfaces.resampling.ResampleSeries>
# 240411-00:09:59,303 nipype.workflow INFO:
# 	 [Node] Finished "fsnative2t1w_xfm", elapsed time 68.325879s.
# 240411-00:12:27,157 nipype.workflow INFO:
# 	 [Node] Finished "boldref_bold", elapsed time 203.496284s.
# 240411-00:12:27,522 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.norm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/norm".
# 240411-00:12:27,523 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.dvars" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/dvars".
# 240411-00:12:27,524 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.tcompcor" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/tcompcor".
# 240411-00:12:27,526 nipype.workflow INFO:
# 	 [Node] Executing "norm" <niworkflows.interfaces.fixes.FixHeaderRegistration>
# 240411-00:12:27,676 nipype.workflow INFO:
# 	 [Node] Executing "dvars" <nipype.algorithms.confounds.ComputeDVARS>
# 240411-00:12:27,783 nipype.workflow INFO:
# 	 [Node] Executing "tcompcor" <niworkflows.interfaces.patches.RobustTCompCor>
# 240411-00:13:04,92 nipype.workflow INFO:
# 	 [Node] Finished "dvars", elapsed time 36.414931s.
# 240411-00:13:21,486 nipype.workflow INFO:
# 	 [Node] Finished "tcompcor", elapsed time 53.702489s.
# 240411-00:13:21,980 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.tcc_metadata_filter" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/tcc_metadata_filter".
# 240411-00:13:21,983 nipype.workflow INFO:
# 	 [Node] Executing "tcc_metadata_filter" <fmriprep.interfaces.confounds.FilterDropped>
# 240411-00:13:21,989 nipype.workflow INFO:
# 	 [Node] Finished "tcc_metadata_filter", elapsed time 0.004802s.
# 240411-00:13:23,651 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.tcc_metadata_fmt" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/tcc_metadata_fmt".
# 240411-00:13:23,653 nipype.workflow INFO:
# 	 [Node] Executing "tcc_metadata_fmt" <niworkflows.interfaces.utility.TSV2JSON>
# 240411-00:13:23,657 nipype.workflow INFO:
# 	 [Node] Finished "tcc_metadata_fmt", elapsed time 0.003358s.
# 240411-00:16:09,480 nipype.workflow INFO:
# 	 [Node] Finished "norm", elapsed time 221.953441s.
# 240411-00:16:10,58 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.map_wmmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/map_wmmask".
# 240411-00:16:10,58 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.map_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/map_brainmask".
# 240411-00:16:10,61 nipype.workflow INFO:
# 	 [Node] Executing "map_brainmask" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240411-00:16:10,61 nipype.workflow INFO:
# 	 [Node] Executing "map_wmmask" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240411-00:16:27,156 nipype.workflow INFO:
# 	 [Node] Finished "map_brainmask", elapsed time 17.093877s.
# 240411-00:16:27,429 nipype.workflow INFO:
# 	 [Node] Finished "map_wmmask", elapsed time 17.36663s.
# 240411-00:16:28,97 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.thr_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/thr_brainmask".
# 240411-00:16:28,101 nipype.workflow INFO:
# 	 [Node] Setting-up "_inu_n4_final0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/inu_n4_final/mapflow/_inu_n4_final0".
# 240411-00:16:28,102 nipype.workflow INFO:
# 	 [Node] Executing "thr_brainmask" <nipype.interfaces.ants.utils.ThresholdImage>
# 240411-00:16:28,102 nipype.workflow INFO:
# 	 [Node] Executing "_inu_n4_final0" <nipype.interfaces.ants.segmentation.N4BiasFieldCorrection>
# 240411-00:16:28,527 nipype.workflow INFO:
# 	 [Node] Finished "thr_brainmask", elapsed time 0.424955s.
# 240411-00:16:30,76 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.03_pad_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/03_pad_mask".
# 240411-00:16:30,76 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.dil_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/dil_brainmask".
# 240411-00:16:30,78 nipype.workflow INFO:
# 	 [Node] Executing "dil_brainmask" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:16:30,79 nipype.workflow INFO:
# 	 [Node] Executing "03_pad_mask" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:16:30,304 nipype.workflow INFO:
# 	 [Node] Finished "03_pad_mask", elapsed time 0.22424s.
# 240411-00:16:30,762 nipype.workflow INFO:
# 	 [Node] Finished "dil_brainmask", elapsed time 0.682782s.
# 240411-00:16:32,100 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.get_brainmask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/get_brainmask".
# 240411-00:16:32,102 nipype.workflow INFO:
# 	 [Node] Executing "get_brainmask" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:16:32,781 nipype.workflow INFO:
# 	 [Node] Finished "get_brainmask", elapsed time 0.573055s.
# 240411-00:16:41,30 nipype.workflow INFO:
# 	 [Node] Finished "_inu_n4_final0", elapsed time 12.927049s.
# 240411-00:16:42,137 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.01_atropos" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/01_atropos".
# 240411-00:16:42,139 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_mask0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/apply_mask/mapflow/_apply_mask0".
# 240411-00:16:42,139 nipype.workflow INFO:
# 	 [Node] Executing "01_atropos" <nipype.interfaces.ants.segmentation.Atropos>
# 240411-00:16:42,140 nipype.workflow INFO:
# 	 [Node] Executing "_apply_mask0" <niworkflows.interfaces.nibabel.ApplyMask>
# 240411-00:16:42,899 nipype.workflow INFO:
# 	 [Node] Finished "_apply_mask0", elapsed time 0.757973s.
# 240411-00:17:08,528 nipype.workflow INFO:
# 	 [Node] Finished "01_atropos", elapsed time 26.284857s.
# 240411-00:17:10,229 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.02_pad_segm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/02_pad_segm".
# 240411-00:17:10,230 nipype.workflow INFO:
# 	 [Node] Executing "02_pad_segm" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:17:10,520 nipype.workflow INFO:
# 	 [Node] Finished "02_pad_segm", elapsed time 0.288571s.
# 240411-00:17:12,236 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.04_sel_labels" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/04_sel_labels".
# 240411-00:17:12,238 nipype.workflow INFO:
# 	 [Node] Executing "04_sel_labels" <nipype.interfaces.utility.wrappers.Function>
# 240411-00:17:12,401 nipype.workflow INFO:
# 	 [Node] Finished "04_sel_labels", elapsed time 0.162231s.
# 240411-00:17:14,225 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.05_get_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/05_get_wm".
# 240411-00:17:14,226 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.06_get_gm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/06_get_gm".
# 240411-00:17:14,226 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.10_me_csf" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/10_me_csf".
# 240411-00:17:14,226 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.27_depad_csf" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/27_depad_csf".
# 240411-00:17:14,228 nipype.workflow INFO:
# 	 [Node] Executing "06_get_gm" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:17:14,228 nipype.workflow INFO:
# 	 [Node] Executing "10_me_csf" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:17:14,228 nipype.workflow INFO:
# 	 [Node] Executing "05_get_wm" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:17:14,229 nipype.workflow INFO:
# 	 [Node] Executing "27_depad_csf" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:17:14,503 nipype.workflow INFO:
# 	 [Node] Finished "27_depad_csf", elapsed time 0.273533s.
# 240411-00:17:14,985 nipype.workflow INFO:
# 	 [Node] Finished "05_get_wm", elapsed time 0.755524s.
# 240411-00:17:15,15 nipype.workflow INFO:
# 	 [Node] Finished "06_get_gm", elapsed time 0.785576s.
# 240411-00:17:16,223 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.09_relabel_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/09_relabel_wm".
# 240411-00:17:16,223 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.07_fill_gm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/07_fill_gm".
# 240411-00:17:16,225 nipype.workflow INFO:
# 	 [Node] Executing "09_relabel_wm" <nipype.interfaces.ants.utils.MultiplyImages>
# 240411-00:17:16,225 nipype.workflow INFO:
# 	 [Node] Executing "07_fill_gm" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:17:16,303 nipype.workflow INFO:
# 	 [Node] Finished "10_me_csf", elapsed time 2.074074s.
# 240411-00:17:16,539 nipype.workflow INFO:
# 	 [Node] Finished "09_relabel_wm", elapsed time 0.312918s.
# 240411-00:17:18,220 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.26_depad_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/26_depad_wm".
# 240411-00:17:18,221 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.anat_fit_wf.brain_extraction_wf.atropos_wf.apply_wm_prior" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/anat_fit_wf/brain_extraction_wf/atropos_wf/apply_wm_prior".
# 240411-00:17:18,222 nipype.workflow INFO:
# 	 [Node] Executing "26_depad_wm" <nipype.interfaces.ants.utils.ImageMath>
# 240411-00:17:18,223 nipype.workflow INFO:
# 	 [Node] Executing "apply_wm_prior" <nipype.interfaces.utility.wrappers.Function>
# 240411-00:17:18,501 nipype.workflow INFO:
# 	 [Node] Finished "26_depad_wm", elapsed time 0.277745s.
# 240411-00:17:18,786 nipype.workflow INFO:
# 	 [Node] Finished "apply_wm_prior", elapsed time 0.56214s.
# 240411-00:17:19,501 nipype.workflow INFO:
# 	 [Node] Finished "07_fill_gm", elapsed time 3.275487s.
# 240411-00:17:20,263 nipype.workflow INFO:
# ...
# 240411-09:28:22,816 nipype.workflow INFO:
# 	 [Node] Executing "compare_transforms" <nipype.interfaces.utility.wrappers.Function>
# 240411-09:28:22,839 nipype.workflow INFO:
# 	 [Node] Finished "compare_transforms", elapsed time 0.022621s.
# 240411-09:28:25,533 nipype.workflow INFO:
# 	 [Node] Finished "acc_masks", elapsed time 4.34178s.
# 240411-09:28:28,876 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.bold_reg_wf.bbreg_wf.concat_xfm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/bold_reg_wf/bbreg_wf/concat_xfm".
# 240411-09:28:28,878 nipype.workflow INFO:
# 	 [Node] Executing "concat_xfm" <niworkflows.interfaces.nitransforms.ConcatenateXFMs>
# 240411-09:28:28,881 nipype.workflow INFO:
# 	 [Node] Finished "concat_xfm", elapsed time 0.002324s.
# 240411-09:28:32,854 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.func_fit_reports_wf.t1w_boldref" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/func_fit_reports_wf/t1w_boldref".
# 240411-09:28:32,856 nipype.workflow INFO:
# 	 [Node] Executing "t1w_boldref" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240411-09:28:32,947 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.t1w_mask_tfm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/t1w_mask_tfm".
# 240411-09:28:32,948 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.func_fit_reports_wf.boldref_wm" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/func_fit_reports_wf/boldref_wm".
# 240411-09:28:32,951 nipype.workflow INFO:
# 	 [Node] Executing "boldref_wm" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240411-09:28:32,952 nipype.workflow INFO:
# 	 [Node] Executing "t1w_mask_tfm" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240411-09:28:33,158 nipype.workflow INFO:
# 	 [Node] Finished "boldref_wm", elapsed time 0.206203s.
# 240411-09:28:34,674 nipype.workflow INFO:
# 	 [Node] Finished "t1w_boldref", elapsed time 1.8168419999999998s.
# 240411-09:28:34,904 nipype.workflow INFO:
# 	 [Node] Finished "seg_rpt", elapsed time 14.012121s.
# 240411-09:28:34,966 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_tfm0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_tfm/mapflow/_acc_msk_tfm0".
# 240411-09:28:34,967 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_tfm1" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_tfm/mapflow/_acc_msk_tfm1".
# 240411-09:28:34,968 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_tfm2" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_tfm/mapflow/_acc_msk_tfm2".
# 240411-09:28:34,968 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_tfm0" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240411-09:28:34,969 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_tfm1" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240411-09:28:34,970 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_tfm2" <niworkflows.interfaces.fixes.FixHeaderApplyTransforms>
# 240411-09:28:35,162 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.func_fit_reports_wf.epi_t1_report" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/func_fit_reports_wf/epi_t1_report".
# 240411-09:28:35,164 nipype.workflow INFO:
# 	 [Node] Executing "epi_t1_report" <nireports.interfaces.reporting.base.SimpleBeforeAfterRPT>
# 240411-09:28:35,164 nipype.interface INFO:
# 	 Report - setting before (/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_out/sub-03/func/sub-03_task-prefuspost_desc-coreg_boldref.nii.gz) and after (/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/func_fit_reports_wf/t1w_boldref/sub-03_desc-preproc_T1w_trans.nii.gz) images
# 240411-09:28:35,164 nipype.interface INFO:
# 	 Generating visual report
# 240411-09:28:35,668 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_tfm2", elapsed time 0.697642s.
# 240411-09:28:35,673 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_tfm1", elapsed time 0.702471s.
# 240411-09:28:35,742 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_tfm0", elapsed time 0.772644s.
# 240411-09:28:36,490 nipype.workflow INFO:
# 	 [Node] Finished "t1w_mask_tfm", elapsed time 3.536461s.
# 240411-09:28:36,984 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.union_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/union_mask".
# 240411-09:28:36,986 nipype.workflow INFO:
# 	 [Node] Executing "union_mask" <nipype.interfaces.utility.wrappers.Function>
# 240411-09:28:36,987 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_tfm0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_tfm/mapflow/_acc_msk_tfm0".
# 240411-09:28:36,988 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_tfm0" - collecting precomputed outputs
# 240411-09:28:36,988 nipype.workflow INFO:
# 	 [Node] "_acc_msk_tfm0" found cached.
# 240411-09:28:36,989 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_tfm1" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_tfm/mapflow/_acc_msk_tfm1".
# 240411-09:28:36,989 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_tfm1" - collecting precomputed outputs
# 240411-09:28:36,989 nipype.workflow INFO:
# 	 [Node] "_acc_msk_tfm1" found cached.
# 240411-09:28:36,990 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_tfm2" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_tfm/mapflow/_acc_msk_tfm2".
# 240411-09:28:36,990 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_tfm2" - collecting precomputed outputs
# 240411-09:28:36,991 nipype.workflow INFO:
# 	 [Node] "_acc_msk_tfm2" found cached.
# 240411-09:28:37,1 nipype.workflow INFO:
# 	 [Node] Finished "union_mask", elapsed time 0.014567s.
# 240411-09:28:38,901 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.dilated_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/dilated_mask".
# 240411-09:28:38,903 nipype.workflow INFO:
# 	 [Node] Executing "dilated_mask" <niworkflows.interfaces.morphology.BinaryDilation>
# 240411-09:28:38,941 nipype.workflow INFO:
# 	 [Node] Finished "dilated_mask", elapsed time 0.037203s.
# 240411-09:28:40,902 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.subtract_mask" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/subtract_mask".
# 240411-09:28:40,902 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_brain0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_brain/mapflow/_acc_msk_brain0".
# 240411-09:28:40,902 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_brain1" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_brain/mapflow/_acc_msk_brain1".
# 240411-09:28:40,902 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_brain2" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_brain/mapflow/_acc_msk_brain2".
# 240411-09:28:40,904 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_brain0" <niworkflows.interfaces.nibabel.ApplyMask>
# 240411-09:28:40,904 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_brain1" <niworkflows.interfaces.nibabel.ApplyMask>
# 240411-09:28:40,904 nipype.workflow INFO:
# 	 [Node] Executing "subtract_mask" <niworkflows.interfaces.morphology.BinarySubtraction>
# 240411-09:28:40,904 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_brain2" <niworkflows.interfaces.nibabel.ApplyMask>
# 240411-09:28:40,915 nipype.workflow INFO:
# 	 [Node] Finished "subtract_mask", elapsed time 0.01021s.
# 240411-09:28:40,946 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_brain2", elapsed time 0.04176s.
# 240411-09:28:40,946 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_brain1", elapsed time 0.041891s.
# 240411-09:28:40,977 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_brain0", elapsed time 0.071997s.
# 240411-09:28:41,111 nipype.workflow INFO:
# 	 [Node] Finished "epi_t1_report", elapsed time 5.947146s.
# 240411-09:28:42,915 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_fit_wf.func_fit_reports_wf.ds_epi_t1_report" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_fit_wf/func_fit_reports_wf/ds_epi_t1_report".
# 240411-09:28:42,915 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_brain0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_brain/mapflow/_acc_msk_brain0".
# 240411-09:28:42,916 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_brain0" - collecting precomputed outputs
# 240411-09:28:42,916 nipype.workflow INFO:
# 	 [Node] "_acc_msk_brain0" found cached.
# 240411-09:28:42,917 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_brain1" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_brain/mapflow/_acc_msk_brain1".
# 240411-09:28:42,917 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_brain1" - collecting precomputed outputs
# 240411-09:28:42,917 nipype.workflow INFO:
# 	 [Node] "_acc_msk_brain1" found cached.
# 240411-09:28:42,917 nipype.workflow INFO:
# 	 [Node] Executing "ds_epi_t1_report" <fmriprep.interfaces.DerivativesDataSink>
# 240411-09:28:42,918 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_brain2" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_brain/mapflow/_acc_msk_brain2".
# 240411-09:28:42,918 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_brain2" - collecting precomputed outputs
# 240411-09:28:42,918 nipype.workflow INFO:
# 	 [Node] "_acc_msk_brain2" found cached.
# 240411-09:28:42,921 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.crowncompcor" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/crowncompcor".
# 240411-09:28:42,924 nipype.workflow INFO:
# 	 [Node] Finished "ds_epi_t1_report", elapsed time 0.005921s.
# 240411-09:28:42,965 nipype.workflow INFO:
# 	 [Node] Executing "crowncompcor" <niworkflows.interfaces.patches.RobustACompCor>
# 240411-09:28:46,908 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_bin0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin0".
# 240411-09:28:46,909 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_bin1" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin1".
# 240411-09:28:46,909 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_bin2" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin2".
# 240411-09:28:46,910 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_bin0" <niworkflows.interfaces.nibabel.Binarize>
# 240411-09:28:46,910 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_bin1" <niworkflows.interfaces.nibabel.Binarize>
# 240411-09:28:46,911 nipype.workflow INFO:
# 	 [Node] Executing "_acc_msk_bin2" <niworkflows.interfaces.nibabel.Binarize>
# 240411-09:28:46,936 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_bin1", elapsed time 0.025193s.
# 240411-09:28:46,937 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_bin2", elapsed time 0.025458s.
# 240411-09:28:46,946 nipype.workflow INFO:
# 	 [Node] Finished "_acc_msk_bin0", elapsed time 0.034884s.
# 240411-09:28:48,920 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_bin0" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin0".
# 240411-09:28:48,921 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_bin0" - collecting precomputed outputs
# 240411-09:28:48,921 nipype.workflow INFO:
# 	 [Node] "_acc_msk_bin0" found cached.
# 240411-09:28:48,921 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_bin1" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin1".
# 240411-09:28:48,922 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_bin1" - collecting precomputed outputs
# 240411-09:28:48,922 nipype.workflow INFO:
# 	 [Node] "_acc_msk_bin1" found cached.
# 240411-09:28:48,922 nipype.workflow INFO:
# 	 [Node] Setting-up "_acc_msk_bin2" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acc_msk_bin/mapflow/_acc_msk_bin2".
# 240411-09:28:48,922 nipype.workflow INFO:
# 	 [Node] Cached "_acc_msk_bin2" - collecting precomputed outputs
# 240411-09:28:48,922 nipype.workflow INFO:
# 	 [Node] "_acc_msk_bin2" found cached.
# 240411-09:28:50,929 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.acompcor" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/acompcor".
# 240411-09:28:50,938 nipype.workflow INFO:
# 	 [Node] Executing "acompcor" <niworkflows.interfaces.patches.RobustACompCor>
# 240411-09:28:52,945 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.signals" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/signals".
# 240411-09:28:52,945 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_03_wf.bold_task_prefuspost_wf.bold_confounds_wf.rois_plot" in "/Users/jacekdmochowski/PROJECTS/fus/data/fmriprep_working/fmriprep_23_2_wf/sub_03_wf/bold_task_prefuspost_wf/bold_confounds_wf/rois_plot".
# 240411-09:28:52,948 nipype.workflow INFO:
# 	 [Node] Executing "rois_plot" <niworkflows.interfaces.reportlets.masks.ROIsPlot>
# 240411-09:28:52,981 nipype.workflow INFO:
# 	 [Node] Executing "signals" <niworkflows.interfaces.images.SignalExtraction>
# 240411-09:29:08,380 nipype.workflow INFO:
# 	 [Node] Finished "signals", elapsed time 15.398471s.
# 240411-09:29:11,821 nipype.workflow INFO:
# 	 [Node] Finished "rois_plot", elapsed time 18.871934s.
